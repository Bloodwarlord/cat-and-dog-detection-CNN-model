# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import tensorflow as tf
from tensorflow.keras import Sequential
from keras.layers import Conv2D , Dense,Flatten,Dropout,MaxPooling2D

# %%
# model

model= Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation="relu",input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32,kernel_size=(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,kernel_size=(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64,activation="relu"))
model.add(Dropout(0.30))
model.add(Dense(1,activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 64)                1183808
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# %%
batch_size = 16

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

# this is a generator that will read pictures found in
# subfolers of 'data/train', and indefinitely generate
# batches of augmented image data
train_generator = train_datagen.flow_from_directory(
        'training_set/training_set',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 150x150
        batch_size=batch_size,
        class_mode='binary')  # since we use binary_crossentropy loss, we need binary labels

# this is a similar generator, for validation data
validation_generator = test_datagen.flow_from_directory(
        'test_set/test_set',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.

# %%
History=model.fit(
        train_generator,
        steps_per_epoch=2000 // batch_size,
        epochs=30,
        validation_data=validation_generator,
        validation_steps=800 // batch_size)
model.save_weights('first_try.h5')  # always save your weights after training or during training
# Out:
# Epoch 1/30
# 125/125 [==============================] - 8s 64ms/step - loss: 0.4851 - accuracy: 0.7692 - val_loss: 0.4742 - val_accuracy: 0.7738
# Epoch 2/30
# 125/125 [==============================] - 8s 65ms/step - loss: 0.4808 - accuracy: 0.7710 - val_loss: 0.4936 - val_accuracy: 0.7675
# Epoch 3/30
# 125/125 [==============================] - 8s 65ms/step - loss: 0.4759 - accuracy: 0.7738 - val_loss: 0.4355 - val_accuracy: 0.8112
# Epoch 4/30
# 125/125 [==============================] - 8s 65ms/step - loss: 0.4625 - accuracy: 0.7979 - val_loss: 0.4548 - val_accuracy: 0.7900
# Epoch 5/30
# 125/125 [==============================] - 8s 67ms/step - loss: 0.4850 - accuracy: 0.7645 - val_loss: 0.4644 - val_accuracy: 0.7850
# Epoch 6/30
# 125/125 [==============================] - 8s 65ms/step - loss: 0.4627 - accuracy: 0.7945 - val_loss: 0.5412 - val_accuracy: 0.7325
# Epoch 7/30
# 125/125 [==============================] - 8s 65ms/step - loss: 0.4679 - accuracy: 0.7838 - val_loss: 0.7391 - val_accuracy: 0.7462
# Epoch 8/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4602 - accuracy: 0.7868 - val_loss: 0.5544 - val_accuracy: 0.7688
# Epoch 9/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4731 - accuracy: 0.7964 - val_loss: 0.4587 - val_accuracy: 0.8000
# Epoch 10/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4310 - accuracy: 0.7989 - val_loss: 0.4621 - val_accuracy: 0.8037
# Epoch 11/30
# 125/125 [==============================] - 9s 68ms/step - loss: 0.4736 - accuracy: 0.7900 - val_loss: 0.4991 - val_accuracy: 0.8050
# Epoch 12/30
# 125/125 [==============================] - 9s 69ms/step - loss: 0.4695 - accuracy: 0.7990 - val_loss: 0.4159 - val_accuracy: 0.8200
# Epoch 13/30
# 125/125 [==============================] - 10s 78ms/step - loss: 0.4475 - accuracy: 0.7945 - val_loss: 0.4350 - val_accuracy: 0.8112
# Epoch 14/30
# 125/125 [==============================] - 8s 67ms/step - loss: 0.4160 - accuracy: 0.8180 - val_loss: 0.4683 - val_accuracy: 0.8300
# Epoch 15/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4532 - accuracy: 0.8085 - val_loss: 0.4295 - val_accuracy: 0.8025
# Epoch 16/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4333 - accuracy: 0.8120 - val_loss: 0.5409 - val_accuracy: 0.8025
# Epoch 17/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4318 - accuracy: 0.8080 - val_loss: 0.4148 - val_accuracy: 0.8188
# Epoch 18/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4339 - accuracy: 0.8155 - val_loss: 0.3975 - val_accuracy: 0.8425
# Epoch 19/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4290 - accuracy: 0.8085 - val_loss: 0.3866 - val_accuracy: 0.8225
# Epoch 20/30
# 125/125 [==============================] - 8s 65ms/step - loss: 0.4280 - accuracy: 0.8120 - val_loss: 0.4369 - val_accuracy: 0.7975
# Epoch 21/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4530 - accuracy: 0.8080 - val_loss: 0.4991 - val_accuracy: 0.7788
# Epoch 22/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4295 - accuracy: 0.8180 - val_loss: 0.4549 - val_accuracy: 0.8062
# Epoch 23/30
# 125/125 [==============================] - 9s 70ms/step - loss: 0.4140 - accuracy: 0.8150 - val_loss: 0.4538 - val_accuracy: 0.8238
# Epoch 24/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4343 - accuracy: 0.8115 - val_loss: 0.5070 - val_accuracy: 0.7812
# Epoch 25/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4356 - accuracy: 0.8030 - val_loss: 0.4230 - val_accuracy: 0.8288
# Epoch 26/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4288 - accuracy: 0.8250 - val_loss: 0.3843 - val_accuracy: 0.8213
# Epoch 27/30
# 125/125 [==============================] - 8s 67ms/step - loss: 0.4281 - accuracy: 0.8160 - val_loss: 0.3993 - val_accuracy: 0.8163
# Epoch 28/30
# 125/125 [==============================] - 8s 65ms/step - loss: 0.4114 - accuracy: 0.8315 - val_loss: 0.3698 - val_accuracy: 0.8462
# Epoch 29/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4374 - accuracy: 0.8055 - val_loss: 0.5046 - val_accuracy: 0.8238
# Epoch 30/30
# 125/125 [==============================] - 8s 66ms/step - loss: 0.4211 - accuracy: 0.8180 - val_loss: 0.3869 - val_accuracy: 0.8487

# %%
import matplotlib.pyplot as plt
plt.plot(History.history["accuracy"],color="red",label="train")
plt.plot(History.history["val_accuracy"],color="blue",label="test")
plt.legend()
plt.show()

# %%
plt.plot(History.history["loss"],color="red",label="train")
plt.plot(History.history["val_loss"],color="blue",label="test")
plt.legend()
plt.show()
